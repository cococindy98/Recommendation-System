# %%
# !pip install selenium

# %%
from selenium import webdriver

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'C:\Users\PC\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup

# %%
driver= webdriver.Chrome('C:\\Users\\HaeJoon\\Desktop\\driver\\chromedriver')
driver.get('https://www.naver.com')

# %%
import re

# %%
import time

# %%
from selenium.webdriver.common.keys import Keys

# %%
chromedriver = 'C:\\Users\\s_rebca\\Desktop\\chrome\\chromedriver'
# selenium의 webdriver에 앞서 설치한 chromedriver를 연동한다.
driver=webdriver.Chrome(chromedriver)
# driver로 특정페이지를 크롤링한다.

driver.get('https://search.musinsa.com/category/001005')
source=driver.page_source
raw=BeautifulSoup(source,'html.parser')
datas=raw.select('#searchList > li')
for data in datas:
    title=data.select_one('div.article_info > p.item_title').text  #브랜드를 옷이름이라고 착각해서 수정해야합니둥..
    url=data.select_one('div.li_inner > div.list_img > a').attrs['href']
    print(title)
    raw=driver.get(url)
    driver.get(url)
    source2=driver.page_source
    raw2=BeautifulSoup(source2,'html.parser')
    
    #리뷰 페이지가 for 문에서 지정한거 보다 적게 있을 경우 에러뜹니다ㅜㅜ
    #try except로 해결해야할듯
    
    for page in range(3,5):
        driver.implicitly_wait(3)
    
        infos=driver.find_elements_by_css_selector('#wrapStyleEstimateList > div > div > div.postRight > div')
        for info in infos:
            score=raw2.select_one('#wrapStyleEstimateList > div > div > div.postRight > div > div.review-size > div > span')
            a=re.findall('\d+',str(score))
            score_=''.join(a)
            review=info.find_element_by_css_selector('div.pContent > div.summary > div > div.pContent_text > span').text
            
            print('점수:',score_,'\n리뷰\n:',review)  
        
        
            
        #element = WebDriverWait(driver, 30).until(
        #    EC.element_to_be_clickable((By.XPATH, '/*[@id="wrapStyleEstimateList"]/div/div[11]/div[2]/div/a'))
        #)
        #button=driver.find_element_by_xpath('//*[@id="wrapStyleEstimateList"]/div/div[11]/div[2]/div/a[%s]'%page)
        #webdriver.ActionChains(driver).click(button).perform()
        driver.implicitly_wait(3)
        driver.find_element_by_xpath('//*[@id="wrapStyleEstimateList"]/div/div[11]/div[2]/div/a[%s]'%(page+1)).send_keys(Keys.ENTER)
        time.sleep(3)
# Out:
# 그루브라임
# 점수: 8
# 리뷰
# : 170cm 동생 입힌 사진입니다 벽돌색 m사이즈에용
# 색깔 입으니까 더 살고 예뻐요!
# 점수: 8
# 리뷰
# : 두께 적당하고 좋은데 목이 조금 잘 늘어난다는 점이 살짝 아쉽네요
# 점수: 8
# 리뷰
# : 갠쟌네요.. 그냥 독서실 갈 때 친구 집 갈 때 입고 잇어요
# 점수: 8
# 리뷰
# : 가격이 가격이라 그런지 분명 같은 사이즈인데 핏이 다르게 나오네요.. 옷자체는 예뻐요
# 점수: 8
# 리뷰
# : 너무 예뻐요,,ㅠㅠ 처음에 사이즈 잘못와서 바로 교환했는데 그래도 빨리 왔구요!! 가격도 저렴한편인데 예쁘니까ㅜㅠ 너무 맘에 들어용 ღ’ᴗ’ღ 또 주문할게용ㅎㅎ
# 점수: 8
# 리뷰
# : 싼 맛에 산건데 기본으로 입기 좋은 거 같아요 요란한 무늬도 없고 저가 뚠뚠하지 않았으면 베스트 였을 듯
# 점수: 8
# 리뷰
# : 역시 그루브라임 하
# 심플하면서 시그니처 이뻐요
# 점수: 8
# 리뷰
# : 일단 색깔이 예뻐요 근데 살짝 다운해서 샀는데 한 사이즈 크게 사도 될것같아요
# 점수: 8
# 리뷰
# : 요새 계속 이것만 입고 다녀요 ㅋㅋ 색깔 진짜 이쁘고 핏도 좋아요~
# 점수: 8
# 리뷰
# : 색감은 너무 좋은데.. 손목 시보리가 좀 약한 느낌이에요
# 점수: 8
# 리뷰
# : 되게 좋아요 가격이 아주 합리적이고 재질도 튼튼하네요
# 점수: 8
# 리뷰
# : 색깔이쁘고 두께 적당하고 크기도 오버핏이라 좋고 가격도 저렴해서 좋아요 편한하게 입을 맨투맨으로 추천
# 점수: 8
# 리뷰
# : 이가격에 이정도 퀄리티면 이맨투맨 고민 안하셔도 될거같습니다
# 점수: 8
# 리뷰
# : 회색바지랑 입으니까 이쁘네요
# 편하게 잘 입을 거 같습니다 잘 입을게요
# 점수: 8
# 리뷰
# : 입고 다니기 편하고 너무나도 좋아요
#
# 색상도 라이트블루 괜찮네요 ㅎㅎ
#
# 요번 봄 시즌은 이옷으로 버텼습니다
# 점수: 8
# 리뷰
# : 많이 클까봐 걱정했는데 딱 좋아요
# ...

# %%
chromedriver = 'C:\\Users\\s_rebca\\Desktop\\chrome\\chromedriver'
driver=webdriver.Chrome(chromedriver)

driver.get('https://search.musinsa.com/category/001001')
source=driver.page_source
raw=BeautifulSoup(source,'html.parser')
cs = raw.select('#searchList > li ')
for c in cs:
    title=c.select_one('div.article_info > p.item_title').text
    url=data.select_one('div.li_inner > div.list_img > a').attrs['href']
    raw=driver.get(url)
    driver.get(url)
# Out:
# 무신사 스탠다드
# 커버낫
# 그루브라임
# 무신사 스탠다드
# 무신사 스탠다드
# 리
# 후아유
# 후아유
# 무신사 스탠다드
# 이벳필드
# 그루브라임
# 제멋
# 디스이즈네버댓
# 마크 곤잘레스
# 어커버
# 무신사 스탠다드
# 무신사 스탠다드
# 마인드브릿지
# 파르티멘토
# 티떠블유엔
# 칼하트
# 트리플에이
# 디스이즈네버댓
# 예스아이씨
# 브렌슨
# 마크 곤잘레스
# 챔피온
# 마크 곤잘레스
# 엠엠엘지
# 내셔널지오그래픽
# 커버낫
# 챔피온
# 지프
# 로얄라이프
# 예스아이씨
# 리
# 엘엠씨
# 스파오
# 마크 곤잘레스
# 커버낫
# 마크 곤잘레스
# 마크 곤잘레스
# 엘무드
# 무신사 스탠다드
# 챔피온
# 엠엠엘지
# 마크 곤잘레스
# 예일
# 무신사 스탠다드
# 유니스디자인
# 커버낫
# 휠라
# 나이키
# 5252 바이 오아이오아이
# 마크 곤잘레스
# 그루브라임
# 예일
# 마크 곤잘레스
# 마크 곤잘레스
# 커버낫
# 지오다노
# 무신사 스탠다드
# 리
# 리
# 페플
# 비바스튜디오
# 트리플에이
# 아웃도어 프로덕츠
# 휠라
# 챔피온
# 드로우핏
# 챔피온
# 카멜워크
# 커버낫
# 무신사 스탠다드
# 디스이즈네버댓
# 브렌슨
# 마크 곤잘레스
# 예일
# 마크 곤잘레스
# 디폴트벨류
# 이스트쿤스트
# 로얄라이프
# 아디다스
# 마크 곤잘레스
# 커버낫
# 비바스튜디오
# 이에스엔
# 칼하트
# 무신사 스탠다드

# %%
for c in cs:
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-f655530bd3b3> in <module>
# ----> 1 cs.text
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
chromedriver = 'C:\\Users\\s_rebca\\Desktop\\chrome\\chromedriver'
driver=webdriver.Chrome(chromedriver)

driver.get('https://search.musinsa.com/category/001001')
source=driver.page_source
raw=BeautifulSoup(source,'html.parser')
datas = raw.select('#searchList > li > div.li_inner > div.article_info > p.item_title')

# %%
datas
# Out:
# [<p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/covernat/goods">커버낫</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/grooverhyme/goods">그루브라임</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/lee/goods">리</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/whoau/goods">후아유</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/whoau/goods">후아유</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>,
# ...

# %%
chromedriver = 'C:\\Users\\s_rebca\\Desktop\\chrome\\chromedriver'
driver=webdriver.Chrome(chromedriver)

driver.get('https://search.musinsa.com/category/001001')
source=driver.page_source
raw=BeautifulSoup(source,'html.parser')
categor=raw.select('#ui-id-4 > ul:nth-child(2) > li')

for cat in categor:
    url=cat.select_one('#ui-id-4 > ul:nth-child(2) > li>a').attrs['href']
    raw = driver.get(url)
    driver.get(url)
    source2=driver.page_source
    raw2=BeautifulSoup(source2, 'html.parser')
    
    time.sleep(2)
    
    datas2 = raw2.select('#searchList > li > div.li_inner > div.article_info > p.list_info')
    
    for data in datas2:
        title=data.select_one('#searchList > li > div.li_inner > div.article_info > p.list_info > a').text  #브랜드를 옷이름이라고 착각해서 수정해야합니둥..
        url=data.select_one('div.li_inner > div.list_img > a').attrs['href']
        print(title)
        raw=driver.get(url)
        driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-d09ba1e71457> in <module>
#      20     for data in datas2:
#      21         title=data.select_one('#searchList > li > div.li_inner > div.article_info > p.list_info > a').text  #브랜드를 옷이름이라고 착각해서 수정해야합니둥..
# ---> 22         url=data.select_one('div.li_inner > div.list_img > a').attrs['href']
#      23         print(title)
#      24         raw=driver.get(url)
#
# AttributeError: 'NoneType' object has no attribute 'attrs'

# %%
# Out:
# [<p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/covernat/goods">커버낫</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/grooverhyme/goods">그루브라임</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/lee/goods">리</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/whoau/goods">후아유</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/whoau/goods">후아유</a></p>,
#  <p class="item_title"><a href="https://display.musinsa.com/display/brands/musinsastandard/goods">무신사 스탠다드</a></p>,
# ...

# %%
title
# Out:
# '무신사 스탠다드'

# %%
for data in datas:
    url=data.select_one('#ui-id-4 > ul:nth-child(2) > li>a').attrs['href']
    raw = driver.get(url)
    driver.get(url)
    source2=driver.page_source
    raw2=BeautifulSoup(source2, 'html.parser')
# Out:
# https://search.musinsa.com/category/001001
# https://search.musinsa.com/category/001010
# https://search.musinsa.com/category/001011
# https://search.musinsa.com/category/001002

# %%
for data in datas:
    print(data.find('a')['href'])
# Out:
# https://search.musinsa.com/category/001001
# https://search.musinsa.com/category/001010
# https://search.musinsa.com/category/001011
# https://search.musinsa.com/category/001002

# %%
options = headless_options

# %%
headless_options = webdriver.ChromeOptions()
headless_options.add_argument('headless')

# %%
chromedriver = 'C:\\Users\\s_rebca\\Desktop\\chrome\\chromedriver'
# selenium의 webdriver에 앞서 설치한 chromedriver를 연동한다.
driver=webdriver.Chrome(chromedriver)
# driver로 특정페이지를 크롤링한다.

driver.get('https://search.musinsa.com/category/001005')
source=driver.page_source
raw=BeautifulSoup(source,'html.parser')
datas=raw.select('#searchList > li')
for data in datas:
    title=data.select_one('div.article_info > p.item_title').text  #브랜드를 옷이름이라고 착각해서 수정해야합니둥..
    url=data.select_one('div.li_inner > div.list_img > a').attrs['href']
    print(title)
    raw=driver.get(url)
    driver.get(url)
    source2=driver.page_source
    raw2=BeautifulSoup(source2,'html.parser')

# %% [markdown]
# # 이것만 보세요

# %%
chromedriver = 'C:\\Users\PC\프로젝트\.conda\chromedriver.exe'
# selenium의 webdriver에 앞서 설치한 chromedriver를 연동한다.
driver=webdriver.Chrome(chromedriver)
driver.maximize_window()
driver.get('https://store.musinsa.com/app/')
source=driver.page_source
raw=BeautifulSoup(source,'html.parser')

# 카테고리 이름
category = raw.select('#ui-id-4 > ul > li')
print(category)
#카테고리페이지로 이동
for cat in category:
    print('-'*20,cat.text,'-'*20)
    url=cat.select_one('#ui-id-4 > ul > li > a').attrs['href']
    raw=driver.get(url)
    #카테고리 페이지내 두개 이동
    for a in range(2):
        print('-'*30, a+1,'-'*30)
        raw=driver.get(url+'?device=&d_cat_cdv nd=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page='+str(a+1)+'&display_cnt=90&sale_goods=&ex_soldout=&color=&price1=&price2=&exclusive_yn=&size=&tags=&sale_campaign_yn=&timesale_yn=&q=')
        source2=driver.page_source
        raw2=BeautifulSoup(source2,'html.parser')
        
        
        #페이지1, 2에서 상품선택
        datas=raw2.select('#searchList > li')
        for data in datas:
                title=data.select_one('div.article_info > p.list_info > a').attrs['title'] # 옷 이름
                url2=data.select_one('div.li_inner > div.list_img > a').attrs['href']      # 상세 옷 주소
                raw=driver.get(url2)
                source3=driver.page_source
                raw3=BeautifulSoup(source3,'html.parser')
                
                #세부페이지
                # title, brand, 품번 출력
                brands=raw3.select('#product_order_info > div.explan_product.product_info_section > ul > li')[0]
                brand_product_num=brands.text[9:]
                
                #태그 한글..로 된것만 찾음..문제
                tag=raw3.select('#product_order_info > div.explan_product.product_info_section > ul > li.article-tag-list.list > p')
                tag_name=re.compile('[가-힣]+').findall(str(tag))
                # 가격
                price=raw3.select('#product_order_info > div.explan_product.price_info_section > ul > li:nth-child(2) > p.product_article_contents')
                #price_no_dot=re.sub(r"[^a-zA-Z0-9]","",str(price))
                # 가격 형태 11,900  30,000   정규표현식에서 ',' 있으면 이상하게 추출
                # ',' 제거후에 가격에 해당하는 숫자만 추출
                price_real=re.findall('\d+',re.sub(r'[^a-zA-Z0-9]','',str(price)))[0]
                
                #평점
                score_full=raw3.select('#product_order_info > div.explan_product.product_info_section > ul > li:nth-child(6) > p.product_article_contents > a > span.prd-score__rating')
                score=re.findall('\d{1}.\d{1}',str(score_full))
                print(score)
                #연령
                age_full=raw3.select('#graph_summary_area > strong:nth-child(2) > em')
                age=re.findall('\d{2}~\d{2}',str(age_full))
                #성별
                gender=raw3.select_one('#graph_summary_area > span.man.graph_sex_text')
                
                try:
                    for page in range(3,5):
                        driver.implicitly_wait(3)
                        buttons=driver.find_element_by_css_selector('#estimate_goods').click() # 일반후기 클릭
                        webdriver.ActionChains(driver).click(buttons).perform()
                
                        infos=driver.find_elements_by_css_selector('#wrapEstimateList > div > div > div.postRight > div')
                        for info in infos:
                    
                        #유저정보와 리뷰 추출
                            user=info.find_element_by_css_selector('div.profile > p > span.gallery_lv > span').text
                            user_info=info.find_element_by_css_selector('div.connect_product.estimate-item > div.connect_review_info > p').text
                            review=info.find_element_by_css_selector('div.pContent > div.summary > div > div.pContent_text > span').text
            
                            print('사용자:',user,'\n사용자정보\n:',user_info,'\n리뷰\n:',review) 
                        
                    #후기 2페이지 추출 
                        driver.implicitly_wait(3)
                        buttons2=driver.find_elements_by_css_selector('#wrapEstimateList > div > div.nslist_bottom > div.pagination.textRight > div > a')[i]
                        webdriver.ActionChains(driver).click(buttons2).perform()
                        time.sleep(3)
                
                
        
                except:pass
# Out:
# [<li><a href="https://search.musinsa.com/category/001001"> 반팔 티셔츠 <span> (55,128)</span></a></li>, <li><a href="https://search.musinsa.com/category/001010"> 긴팔 티셔츠 <span> (12,916)</span></a></li>, <li><a href="https://search.musinsa.com/category/001011"> 민소매 티셔츠 <span> (2,831)</span></a></li>, <li><a href="https://search.musinsa.com/category/001002"> 셔츠/블라우스 <span> (20,782)</span></a></li>, <li><a href="https://search.musinsa.com/category/001003"> 피케/카라 티셔츠 <span> (4,931)</span></a></li>, <li><a href="https://search.musinsa.com/category/001005"> 맨투맨/스웨트셔츠 <span> (25,016)</span></a></li>, <li><a href="https://search.musinsa.com/category/001004"> 후드 티셔츠 <span> (16,100)</span></a></li>, <li><a href="https://search.musinsa.com/category/001006"> 니트/스웨터 <span> (10,267)</span></a></li>, <li><a href="https://search.musinsa.com/category/001008"> 기타 상의 <span> (791)</span></a></li>]
# --------------------  반팔 티셔츠  (55,128) --------------------
# ...

# %%
chromedriver = 'C:\\Users\PC\프로젝트\.conda\chromedriver.exe'
# selenium의 webdriver에 앞서 설치한 chromedriver를 연동한다.
driver=webdriver.Chrome(chromedriver)
driver.maximize_window()
driver.get('https://search.musinsa.com/category/001005')
source=driver.page_source
raw=BeautifulSoup(source,'html.parser')

# 카테고리 이름
category = raw.select('#ui-id-4 > ul> li')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-8a01a2df91f8> in <module>
#       8
#       9 # 카테고리 이름
# ---> 10 category = raw.select('#ui-id-4 > ul> li')
#
# ~\anaconda3\lib\site-packages\bs4\element.py in select(self, selector, _candidate_generator, limit)
#    1530                     print("    Running candidate generator on %s %s" % (
#    1531                         tag.name, repr(tag.attrs)))
# -> 1532                 for candidate in _use_candidate_generator(tag):
#    1533                     if not isinstance(candidate, Tag):
#    1534                         continue
#
# ~\anaconda3\lib\site-packages\bs4\element.py in recursive_select(tag)
#    1491                         print('    Calling select("%s") recursively on %s %s' % (next_token, tag.name, tag.attrs))
#    1492                         print('-' * 40)
# ...
