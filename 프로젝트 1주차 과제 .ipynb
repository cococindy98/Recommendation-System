# %% [markdown]
# # Challenge1 - IMDb 영화정보 수집하기
# - 현재 상영중인 영화목록에서 상영 중인 영화의 제목/감독/배우 데이터 수집
# - 조건문을 사용하여 Action장르의 영화만 출력하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
raw=requests.get('https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth')
html=BeautifulSoup(raw.text,'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>New Movies In Theaters - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# ...

# %%
import re

# %%
movie=html.select('td.overview-top')
for m in movie:
    title=m.select_one('a').text
    genre=m.select_one('p.cert-runtime-genre span').text
    info=m.select('div.txt-block')
    director=info[0].select('a')
    actor=info[1].select('a')
    for d in director:
        print(d.text)
    for a in actor:
        print(a.text)
# Out:
# Dominic Cooke
# Benedict Cumberbatch
# Merab Ninidze
# Rachel Brosnahan
# Vladimir Chuprikov
# Magnus Martens
# Sam Heughan
# Ruby Rose
# Andy Serkis
# Hannah John-Kamen
# Paolo Pilladi
# Jeremy Piven
# Taryn Manning
# Bruce Dern
# Zach McGowan
# BenDavid Grabinski
# Joel McHale
# Natalie Zea
# Natalie Morales
# Kerry Bishé
# Brad Furman
# Johnny Depp
# Forest Whitaker
# Toby Huss
# Dayton Callie

# %%
#컨테이너 수집
movie=html.select('td.overview-top')
for m in movie:
    title=m.select_one('a').text
    genre=m.select_one('p.cert-runtime-genre span').text
    director=m.select_one('div.txt-block span a').text
    actors=m.select('div.txt-block a')
    
    a=[]
    for i in range(1,len(actors)):
        actor=actors[i].text
        a.append(actor)
    if genre=='Action' :
        print(title,genre)
        print(director)
        print(a)
    
#조건문을 사용하여 Action장르만 뽑아내깅~
# Out:
#  SAS: Red Notice (2021) Action
# Magnus Martens
# ['Sam Heughan', 'Ruby Rose', 'Andy Serkis', 'Hannah John-Kamen']

# %% [markdown]
# # Challenge2 - IMDb 포스터 저장하기
# - 현재 상영중인 영화목록에서 현재 상영중 영화의 상세페이지에 접속해 포스터 저장
# - 링크주소를 수집하기
# - 포스터 이미지가 저장되어 있는 속성을 찾아 포스터를 다운받기

# %%
raw=requests.get('https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth')
html=BeautifulSoup(raw1.text,'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>New Movies In Theaters - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# ...

# %%
import urllib.request

movie=html.select('td.overview-top')
for m in movie:
    title=m.select_one('a')
    url=title.attrs['href']
    #print(title.text)
    #print('https://www.imdb.com/'+url)
    
    each_raw=requests.get('https://www.imdb.com/'+url)
    each_html=BeautifulSoup(each_raw.text,'html.parser')
    
    #이미지를 poster폴더에 저장
    try:
        poster=each_html.select_one('div.poster a img')
        img=poster.attrs['src']
        #print(img)
        urllib.request.urlretrieve(img,'poster/'+title.text+'.png')
    except:
        continue

# %% [markdown]
# # Homework-네이버 쇼핑 best100데이터 수집하기
# - 각 제품 상세페이지로 들어갈 수 있는 링크 찾기
# - 상세페이지에서 원하는 데이터를 찾을 수 있는 선택자 찾기

# %%
new_raw=requests.get('https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000',headers={'User-Agent':'Mozilla/5.0'})
new_html=BeautifulSoup(new_raw.text,'html.parser')

items=new_html.select('li._itemSection')
for item in items:
    cont=item.select_one('div.thumb_area a')
    url=cont.attrs['href']
    #print(url)
    name=item.select_one('p.cont a').text
    rank=item.select_one('div.thumb_area > div > em').text
    print(name)
    print('상품순위:',rank)
    
    each_raw=requests.get(url,headers={'User-Agent':'Mozilla/5.0'})
    each_html=BeautifulSoup(each_raw.text,'html.parser')
    
    
    infos=each_html.select('div.summary_info_area__3XT5U')
    #print(infos)
    for info in infos:
        price=info.select_one('div.lowestPrice_price_area__OkxBK > div.lowestPrice_low_price__fByaG').text
        mall=info.select_one('div.condition_area > table > tbody > tr > td.productByMall_mall_area__1oEU_ > div').text
        mall_price=info.select_one('div.condition_area > table > tbody > tr > td.productByMall_price__3F_YF').text
        link=info.select_one('div.condition_area > table > tbody > tr > td.productByMall_buy_area__1iDTI > a').attrs['href']
        print('최저가:',price)
        print('인기순판매처:',mall,'가격:',mall_price)
        print('인기순 판매처 링크;\n',link)
# Out:
# 지오다노 어니언 퀄팅 경량다운 자켓 37090...
# 상품순위: 1
# 최저가: 최저 33,480원
# 인기순판매처:  가격: 41,180
# 인기순 판매처 링크;
# ...
